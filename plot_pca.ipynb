# %%
# %matplotlib inline

# %% [markdown]
# # Demo PCA in 2D

# %% [markdown]
# Load the iris data

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target
X.shape
# Out:
# (150, 4)

# %%
from matplotlib import pyplot as plt

target_ids = range(len(iris.target_names))
plt.figure(figsize=(6, 5))
for i, c, label in zip(target_ids, 'rgbcmykw', iris.target_names):
    plt.scatter(X[y==i,0], X[y==i,1], c=c, label=label)
plt.legend()
plt.show()

# %% [markdown]
# Fit a PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3, whiten=True)
pca.fit(X)
X_pca = pca.transform(X)
# Out:
# PCA(n_components=3, whiten=True)

# %%
import numpy as np
X_pca = pca.transform(X)

Xc = X - X.mean(axis=0)
Xc.shape
C = Xc.T @ Xc
l, ev = np.linalg.eig(C)
C.shape
print(l.shape)
X_pca = (X @ ev)
# Out:
# (4,)

# %% [markdown]
# Project the data in 2D

# %% [markdown]
# Visualize the data

# %%
target_ids = range(len(iris.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
for i, c, label in zip(target_ids, 'rgbcmykw', iris.target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1],
               c=c, label=label)
plt.legend()
plt.show()

# %% [markdown]
# avec numpy
#
# programmer l'ACP ( PCA )
#
# - centrer X => Xc
# - calculer la matrice de covariance => C
# - decomposer en valeurs propres / vecteurs propres => l, ev
# - reprojeter en calculant X_pca = X @ ev
# - afficher
